# %% [markdown]
# # Before you start :
#    - These exercises are related to the Pivot table and correlation lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Open the ` Employee.csv` file and name your dataset `employee`.

# %%
employee = pd.read_csv("Employee.csv")
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### What's the mean salary by department?
# Hint : There are 2 ways to do it - one way is with groupby and the other way is with pivot tables. Do it both ways.

# %%
salary_average = employee.groupby('Department')['Salary'].mean()
print(salary_average)
# Out:
# Department
# HR       45.00
# IT       48.75
# Sales    55.00
# Name: Salary, dtype: float64

# %%
employee.pivot_table(index=['Department', 'Title'], values = ['Salary'],aggfunc = ['mean']).reset_index()
# Out:
#   Department      Title   mean
#                         Salary
# 0         HR         VP   70.0
# 1         HR    analyst   32.5
# 2         IT         VP   70.0
# 3         IT    analyst   32.5
# 4         IT  associate   60.0
# 5      Sales  associate   55.0

# %% [markdown]
# #### We want now to group the data by more than one column. Use Pandas pivot table function to select the mean salary by department and title.

# %%
employee.groupby(['Department', 'Title']).agg({'Salary':np.mean})
# Out:
#                       Salary
# Department Title
# HR         VP           70.0
#            analyst      32.5
# IT         VP           70.0
#            analyst      32.5
#            associate    60.0
# Sales      associate    55.0

# %% [markdown]
# #### We want to display the number of years of work experience and the salary for each Title. Add Years as a column in your pivot table.
# *Hint: Use Pandas doc(see References in README.md) to explore the pivot_table() arguments*

# %%
employee.pivot_table(index=['Years', 'Title'], values = ['Salary'],aggfunc = ['max']).reset_index()
# Out:
#   Years      Title    max
#                    Salary
# 0     1    analyst     35
# 1     2    analyst     30
# 2     2  associate     55
# 3     3  associate     55
# 4     4    analyst     35
# 5     7  associate     60
# 6     8         VP     70

# %% [markdown]
# #### We want to know the information about the mean salary and number of employees in each department and for each job title.

# %%
salary_average = employee.groupby('Department','Title')['Salary'].mean()
print(salary_average)

# %% [markdown]
# #### We want to know for each department and for each job title the Salary's median, minimum, maximum and standard deviation. Comment your results.

# %%
df = employee.groupby(['Department', 'Title']).agg({'Salary':np.mean, 'Gender':pd.Series.nunique})
df.head()
df.columns = ['Avg-Salary', 'No_Employee']
df
# Out:
#                       Avg-Salary  No_Employee
# Department Title
# HR         VP               70.0            1
#            analyst          32.5            2
# IT         VP               70.0            1
#            analyst          32.5            2
#            associate        60.0            1
# Sales      associate        55.0            2

# %%
employee.groupby(['Title', 'Department']).describe()['Salary'].reset_index()
# Out:
#        Title Department  count  mean       std   min    25%   50%    75%   max
# 0         VP         HR    1.0  70.0       NaN  70.0  70.00  70.0  70.00  70.0
# 1         VP         IT    1.0  70.0       NaN  70.0  70.00  70.0  70.00  70.0
# 2    analyst         HR    2.0  32.5  3.535534  30.0  31.25  32.5  33.75  35.0
# 3    analyst         IT    2.0  32.5  3.535534  30.0  31.25  32.5  33.75  35.0
# 4  associate         IT    1.0  60.0       NaN  60.0  60.00  60.0  60.00  60.0
# 5  associate      Sales    2.0  55.0  0.000000  55.0  55.00  55.0  55.00  55.0

# %% [markdown]
# #### Based on your comments, fill the missing values with an appropriate value.

# %%
# std = 0 means there's not difference between the mean and he error so as all the numbers of min max and %s are the same, we'll fill the NaN numbers by 0.  
stats = employee.groupby(['Title', 'Department']).describe()['Salary'].reset_index()
stats['std'].fillna('0', inplace=True)
stats
# Out:
#        Title Department  count  mean       std   min    25%   50%    75%   max
# 0         VP         HR    1.0  70.0         0  70.0  70.00  70.0  70.00  70.0
# 1         VP         IT    1.0  70.0         0  70.0  70.00  70.0  70.00  70.0
# 2    analyst         HR    2.0  32.5  3.535534  30.0  31.25  32.5  33.75  35.0
# 3    analyst         IT    2.0  32.5  3.535534  30.0  31.25  32.5  33.75  35.0
# 4  associate         IT    1.0  60.0         0  60.0  60.00  60.0  60.00  60.0
# 5  associate      Sales    2.0  55.0       0.0  55.0  55.00  55.0  55.00  55.0

# %% [markdown]
# #### The stake holders want to know for each department the number of employees and how much money is spend on salaries. Could you provide that information?

# %%
employee.pivot_table(index=['Department'], values = ['Salary', 'Name'], aggfunc = {'Salary': 'sum', 'Name':'count'})
df.head()
# Out:
#                       Avg-Salary  No_Employee
# Department Title
# HR         VP               70.0            1
#            analyst          32.5            2
# IT         VP               70.0            1
#            analyst          32.5            2
#            associate        60.0            1

# %% [markdown]
# #### For each Department and Title, we want to know the the total years of work experience and the mean salary.

# %%
employee.groupby(['Department', 'Title']).agg({'Salary':np.mean,'Years':sum}).reset_index()
df.head()
# Out:
#                       Avg-Salary  No_Employee
# Department Title
# HR         VP               70.0            1
#            analyst          32.5            2
# IT         VP               70.0            1
#            analyst          32.5            2
#            associate        60.0            1

# %% [markdown]
# ### Bonus
#
# #### We now want to compute the mean salary after removing the maxima for each Department. Create the appropriate pivot table.
#
# Hint: Write a custom function.

# %%
# your answer here
